# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('F1Score_55-66 - Grouping_Labels(score=0.25).csv')
df.head()

# %%
defect_label2 = np.unique(df.Labels.to_list())
df_features = df[['Labels','Train_Images', 'Model', 'Train_F1']]
defect_label = []
for x in defect_label2:
    if len(df_features.loc[df_features['Labels']==x])>1:
        defect_label.append(x)
#     print(x)

# %%
df_features = df[['Labels','Train_Images', 'Model', 'Train_F1']]
# df_features.sort_values('Train_F1')
for idxd, deflabel_ in enumerate(defect_label):
    plt.rcParams["figure.figsize"] = (10,10)
    plt.rcParams['figure.facecolor']='white'
    horblack = df_features.loc[df_features['Labels']==defect_label[idxd]]
    
    # horblack_sorted = horblack.sort_values('Train_F1')
    horblack_train_labels = horblack[['Train_Images', 'Labels']]
    horblack_imgs = np.asarray(horblack_train_labels[['Train_Images']])
    horblack_imgs.reshape(-1, 1)

    f1_horblack_model = horblack[['Model', 'Train_F1']]
    f1_horblack = np.asarray(f1_horblack_model[['Train_F1']])

    
    model_name = np.unique(f1_horblack_model.Model.to_list())
    label_name = np.unique(horblack_train_labels.Labels.to_list())
    ln = []
    for idxm, model in enumerate(model_name):
        ln.append(model)
    sc = StandardScaler()
    horblack_imgs_sc = sc.fit_transform(horblack_imgs)
    X_set, y_set = sc.inverse_transform(horblack_imgs_sc), f1_horblack
    X1 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 10, stop=X_set[:, 0].max() + 10))
    # print(len(horblack), len(f1_horblack))
    # print(len(X_set), len(y_set))
    plt.xlim(0, X1[0].max())
    plt.ylim(-1, 1)

    for idx, _ in enumerate(X_set):
        # print(_, y_set[idx])
        plt.scatter(_, y_set[idx], s=100)

    
    plt.title(f'Korelasi Jumlah Gambar {defect_label[idxd]} dan F1-Score (Training)- {len(horblack)} data')
    plt.xlabel('Jumlah Gambar')
    plt.ylabel('F1-Score')
    plt.legend(ln, loc=8)
    plt.savefig(f'class_train/{defect_label[idxd]}_train.png')
    plt.show()

    # print()
    horblack = df_features

# %%
df_features = df[['Labels','Val_Images', 'Model', 'Val_F1']]
for idxd, deflabel_ in enumerate(defect_label):
    
    plt.rcParams["figure.figsize"] = (10,10)
    plt.rcParams['figure.facecolor']='white'
    horblack = df_features.loc[df_features['Labels']==defect_label[idxd]]
    # horblack_sorted = horblack.sort_values('Val_F1')
    horblack_Val_labels = horblack[['Val_Images', 'Labels']]
    horblack_imgs = np.asarray(horblack_Val_labels[['Val_Images']])
    horblack_imgs.reshape(-1, 1)

    f1_horblack_model = horblack[['Model', 'Val_F1']]
    f1_horblack = np.asarray(f1_horblack_model[['Val_F1']])

    # horblack_sorted
    model_name = np.unique(f1_horblack_model.Model.to_list())
    label_name = np.unique(horblack_Val_labels.Labels.to_list())
    ln = []
    for idxm, model in enumerate(model_name):
        ln.append(model)
    sc = StandardScaler()
    horblack_imgs_sc = sc.fit_transform(horblack_imgs)
    X_set, y_set = sc.inverse_transform(horblack_imgs_sc), f1_horblack
    X1 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 10, stop=X_set[:, 0].max() + 10))
    plt.xlim(0, X1[0].max())
    plt.ylim(-1, 1)

    for idx, _ in enumerate(X_set):
        plt.scatter(_, y_set[idx], s=100
        )
    plt.title(f'Korelasi Jumlah Gambar {defect_label[idxd]} dan F1-Score (Validation)- {len(horblack)} data')
    plt.xlabel('Jumlah Gambar')
    plt.ylabel('F1-Score')
    plt.legend(ln, loc=8)
    plt.savefig(f'class_val/{defect_label[idxd]}_val.png')
    plt.show()

# %%
df_features = df[['Labels','Test_Images', 'Model', 'Test_F1']]
for idxd, deflabel_ in enumerate(defect_label):
    plt.rcParams["figure.figsize"] = (10,10)
    plt.rcParams['figure.facecolor']='white'
    horblack = df_features.loc[df_features['Labels']==defect_label[idxd]]
    # horblack_sorted = horblack.sort_values('Test_F1')
    horblack_Test_labels = horblack[['Test_Images', 'Labels']]
    horblack_imgs = np.asarray(horblack_Test_labels[['Test_Images']])
    horblack_imgs.reshape(-1, 1)

    f1_horblack_model = horblack[['Model', 'Test_F1']]
    f1_horblack = np.asarray(f1_horblack_model[['Test_F1']])

    # horblack_sorted
    model_name = np.unique(f1_horblack_model.Model.to_list())
    label_name = np.unique(horblack_Test_labels.Labels.to_list())
    ln = []
    for idxm, model in enumerate(model_name):
        ln.append(model)
    sc = StandardScaler()
    horblack_imgs_sc = sc.fit_transform(horblack_imgs)
    X_set, y_set = sc.inverse_transform(horblack_imgs_sc), f1_horblack
    X1 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 10, stop=X_set[:, 0].max() + 10))
    plt.xlim(0, X1[0].max())
    plt.ylim(-1, 1)

    for idx, _ in enumerate(X_set):
        plt.scatter(_, y_set[idx], s=100
        )

    plt.title(f'Korelasi Jumlah Gambar {defect_label[idxd]} dan F1-Score (Testing)- {len(horblack)} data')
    plt.xlabel('Jumlah Gambar')
    plt.ylabel('F1-Score')
    plt.legend(ln, loc=8)
    plt.savefig(f'class_test/{defect_label[idxd]}_Test.png')
    plt.show()
